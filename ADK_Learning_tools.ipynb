# %% [markdown]
# # 🚀 Welcome to Your ADK Adventure - Tools & Memory! 🚀
#
# Welcome, Agent Architect! This notebook is your guide to giving your AI agents two essential superpowers: custom tools and conversational memory.
#
# By the end of this adventure, you will be able to:
#
# - **Build a Foundational Agent**: Create a simple but effective AI agent from scratch using the Google Agent Development Kit (ADK).
#
# - **Grant New Skills with Custom Tools**: Teach an agent to perform new tasks by connecting it to external APIs, like a real-time weather service.
#
# - **Create a Team of Agents**: Assemble a multi-agent system where a primary agent can delegate specialized tasks to other agents.
#
# - **Master Conversational Memory**: Understand the critical role of Sessions in enabling agents to remember previous interactions, handle feedback, and carry on a coherent conversation.
#
#
# Let's get this adventure started!

# %% [markdown]
# ## Author
#
# HI, I'm Qingyue (Annie) Wang, a developer advocate and AI engineer at **Google**, passionate about helping developers build with AI and cloud technologies :)
#
#
# If you have questions with this notebook, contact me on [LinkedIn](https://www.linkedin.com/in/anniewangtech/) , [X](https://twitter.com/anniewangtech) or email anniewangtech0510@Gmail.com
#
#
# ```
#   (\__/)
#   (•ㅅ•)
#   /づ  📚      Enjoy learning AI Agents :)
# ```

# %% [markdown]
# -------------
# ### 🎁 🛑 Important Prerequisite: Setup Your Environment! 🛑 🎁
# -----------------------------------------------------------------------------
#
# 👉 **Get Your API Key HERE**: https://codelabs.developers.google.com/onramp/instructions#1
#
#  -----------------------------------------------------------------------------

# %% [markdown]
# ```
#  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️
#    /\_/\     /\_/\     /\_/\      /\_/\       /\_/\
#   ( ^_^ )   ( -.- )   ( >_< )   ( =^.^= )    ( o_o )
# ```

# %% [markdown]
# ## Part 0: Setup & Authentication 🔑
#
# First things first, let's get all our tools ready. This step installs the necessary libraries and securely configures your Google API key so your agents can access the power of Gemini.

# %%
# !pip install google-adk google-generativeai -q

# --- Import all necessary libraries for our entire adventure ---
import os
import re
import asyncio
from IPython.display import display, Markdown
import google.generativeai as genai
from google.adk.agents import Agent
from google.adk.tools import google_search
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, Session
from google.genai.types import Content, Part
from getpass import getpass

print("✅ All libraries are ready to go!")
# Out:
# ✅ All libraries are ready to go!

# %%
# --- Securely Configure Your API Key ---

# Prompt the user for their API key securely
api_key = getpass('Enter your Google API Key: ')

# Configure the generative AI library with the provided key
genai.configure(api_key=api_key)

# Set the API key as an environment variable for ADK to use
os.environ['GOOGLE_API_KEY'] = api_key

print("✅ API Key configured successfully! Let the fun begin.")
# Out:
# Enter your Google API Key: ··········
# ✅ API Key configured successfully! Let the fun begin.

# %% [markdown]
# ---
# ## Part 1: Your First Agent - The Day Trip Genie 🧞
#
# Meet your first creation! The `day_trip_agent` is a simple but powerful assistant. We're making it a little smarter by teaching it to understand **budget constraints**.
#
# * **Agent**: The brain of the operation, defined by its instructions, tools, and the AI model it uses.
# * **Session**: The conversation history. For this simple agent, it's just a container for a single request-response.
# * **Runner**: The engine that connects the `Agent` and the `Session` to process your request and get a response.

# %% [markdown]
# ```
# +--------------------------------------------------+
# |         Spontaneous Day Trip Agent 🤖            |
# |--------------------------------------------------|
# |  Model: gemini-2.5-flash                         |
# |  Description:                                    |
# |   Generates full-day trip itineraries based on   |
# |   mood, interests, and budget                    |
# |--------------------------------------------------|
# |  🔧 Tools:                                       |
# |   - Google Search                                |
# |--------------------------------------------------|
# |  🧠 Capabilities:                                |
# |   - Budget Awareness (cheap / splurge)           |
# |   - Mood Matching (adventurous, relaxing, etc.)  |
# |   - Real-Time Info (hours, events)               |
# |   - Morning / Afternoon / Evening plan           |
# +--------------------------------------------------+
#
#             ▲
#             |
#     +------------------+
#     |   User Input     |
#     |------------------|
#     |  Mood            |
#     |  Interests       |
#     |  Budget          |
#     +------------------+
#
#             |
#             ▼
#
# +--------------------------------------------------+
# |             Output: Markdown Itinerary           |
# |--------------------------------------------------|
# | - Time blocks (Morning / Afternoon / Evening)    |
# | - Venue names with links and hours               |
# | - Budget-matching activities                     |
# +--------------------------------------------------+
# ```

# %%
# --- Agent Definition ---

def create_day_trip_agent():
    """Create the Spontaneous Day Trip Generator agent"""
    return Agent(
        name="day_trip_agent",
        model="gemini-2.5-flash",
        description="Agent specialized in generating spontaneous full-day itineraries based on mood, interests, and budget.",
        instruction="""
        You are the "Spontaneous Day Trip" Generator 🚗 - a specialized AI assistant that creates engaging full-day itineraries.

        Your Mission:
        Transform a simple mood or interest into a complete day-trip adventure with real-time details, while respecting a budget.

        Guidelines:
        1. **Budget-Aware**: Pay close attention to budget hints like 'cheap', 'affordable', or 'splurge'. Use Google Search to find activities (free museums, parks, paid attractions) that match the user's budget.
        2. **Full-Day Structure**: Create morning, afternoon, and evening activities.
        3. **Real-Time Focus**: Search for current operating hours and special events.
        4. **Mood Matching**: Align suggestions with the requested mood (adventurous, relaxing, artsy, etc.).

        RETURN itinerary in MARKDOWN FORMAT with clear time blocks and specific venue names.
        """,
        tools=[google_search]
    )

day_trip_agent = create_day_trip_agent()
print(f"🧞 Agent '{day_trip_agent.name}' is created and ready for adventure!")
# Out:
# 🧞 Agent 'day_trip_agent' is created and ready for adventure!

# %%
# --- A Helper Function to Run Our Agents ---
# We'll use this function throughout the notebook to make running queries easy.

async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )

    final_response = ""
    try:
        async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):
            if not is_router:
                # Let's see what the agent is thinking!
                print(f"EVENT: {event}")
            if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
        final_response = f"An error occurred: {e}"

    if not is_router:
     print("\n" + "-"*50)
     print("✅ Final Response:")
     display(Markdown(final_response))
     print("-"*50 + "\n")

    return final_response

# --- Initialize our Session Service ---
# This one service will manage all the different sessions in our notebook.
session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %%
# --- Let's test the Day Trip Genie! ---

async def run_day_trip_genie():
    # Create a new, single-use session for this query
    day_trip_session = await session_service.create_session(
        app_name=day_trip_agent.name,
        user_id=my_user_id
    )

    # Note the new budget constraint in the query!
    query = "Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!"
    print(f"🗣️ User Query: '{query}'")

    await run_agent_query(day_trip_agent, query, day_trip_session, my_user_id)

await run_day_trip_genie()
# Out:
# 🗣️ User Query: 'Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!'
#
# 🚀 Running query for agent: 'day_trip_agent' in session: '75d7d31a-da85-4a4b-a866-ed168e59c80f'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Here's a relaxing and artsy day trip plan near Sunnyvale, CA, designed to be affordable:
#
# ---
#
# ## Relaxing & Artsy Day Trip near Sunnyvale, CA (Affordable)
#
# This itinerary focuses on enjoying art and serene environments without breaking the bank, with options for free admission and budget-friendly meals.
#
# ### 🚗 **Morning (10:00 AM - 1:00 PM): Immerse in Art at Cantor Arts Center**
#
# *   **Activity:** Begin your day with a visit to the **Cantor Arts Center at Stanford University**. This renowned museum offers free admission to its diverse collections, including art from various cultures and periods. You can explore the galleries and then take a relaxing stroll through the Rodin Sculpture Garden located outside. The combination of indoor art and outdoor sculptures provides both artistic stimulation and a peaceful environment.
# *   **Cost:** Free admission. Parking is available via Stanford Transportation's ParkMobile App (paid).
# *   **Hours:** On Saturdays and Sundays, the Cantor Arts Center is open from 10:00 AM to 5:00 PM.
# *   **Location:** 328 Lomita Drive, Stanford, CA 94305.
#
# ### 🍽️ **Lunch (1:00 PM - 2:30 PM): Affordable Bites in Palo Alto**
#
# *   **Activity:** Head to downtown Palo Alto, just a short drive from Stanford. Enjoy a casual and affordable lunch.
# *   **Suggestion:** Grab a sandwich from a local deli or enjoy a quick, budget-friendly meal at one of the many eateries. Look for places offering lunch specials or classic casual fare.
# *   **Cost:** ~$10-$20 per person.
#
# ### 🎨 **Afternoon (2:30 PM - 5:30 PM): Stroll and Discover Public Art in Palo Alto**
#
# *   **Activity:** After lunch, take a leisurely walk through downtown Palo Alto. Explore the charming streets, enjoy some window shopping, and appreciate the city's architecture. Palo Alto also has various public art installations that you might discover during your stroll, offering a relaxed continuation of your artsy theme. The Palo Alto Art Center also has exhibition galleries open on Saturdays until 5:00 PM, and Sundays from 1:00 PM – 5:00 PM, which could be another free art stop if time permits.
# *   **Cost:** Free.
#
# ### 🍜 **Evening (6:00 PM onwards): Affordable Dinner & Relaxed Evening in Sunnyvale**
#
# *   **Activity:** Head back towards Sunnyvale for an affordable and satisfying dinner.
# *   **Suggestion:** Sunnyvale offers a variety of budget-friendly dining options. Consider **Madras Cafe** for delicious and affordable South Indian cuisine, known for its dosas. Alternatively, explore the diverse range of Mexican food trucks in the area, such as **El Califas Taco Truck** or **Taqueria Pátzcuaro**, which are known for their great value and taste.
# *   **Cost:** ~$10-$20 per person.
# *   **Evening Relaxation:** After dinner, you could enjoy a peaceful evening stroll in one of Sunnyvale's parks, such as **Baylands Park** (open until sunset), or explore areas with interesting lighting if available. For a truly artsy end to the day, consider looking at the City of Sunnyvale's public art collection online, which offers self-guided tour maps for various districts.
#
# ---
#
# Enjoy your relaxing and artsy day trip!"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='stanford.edu',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG4Yjb8GkMamVwfaFUXRdQ5clrCSVkehdOuRsRVvpaM8EIa3q4oYYN3sn1jg7JCDlO-RQg-DeKreheTo64inCML3MBE9vkdjOLXtCzbQHceYkkLuvQSDkmN4EyPrKPR6HPuG2BRibzb2I8='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wheree.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF9NolYF6iMgBcuWQytKWrrNl5Il7HXbTB0fj69fwzYMmS7_3FibKQB9LhH8p2r_1HryJN39Hd5YU2epC9flE7X4bSFg541XCUsXAk4-rQSBoDcT_ZTBQ5daqRzTLeUt4LeHYHIpbSLFpujrgOakQnISI2QrSNxS6M='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='paloalto.gov',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHUnMrOGtBnTH5JP_ZqV8BlQt4raTqwLwWe67_sySYqdkIjeoYlzn-6x0vviKSdLBtV3t6eUqplRcBNBcwMxfg8FmLhoI1Cjpub1uBJX1NReCx9HUMXnh-JETLB9Ngh140bXQ0TgYwdu3NQXfcz3QUoenSC-PtNpFTa0O50HZ0kWQOW73ciUmkcawE8VyB1Xatp9VNI5A=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='paloalto.gov',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFtTmpF7ADTKxa9vP7hOtlpN9O38iSeJhCoTt-LK5JGLylxr3OKPkFK9jlVV4NBn-d_dIRrLRMgZc899J9e3oqqliEH_8E73f774ualyggWlVtcPBl-UYgDMR7pSREFVsyMpih6_qZHTodIbuSfmdmnfT2jb6CFzjJnBkOYbunxkeHJ7Azs2k4lqiifRcMi2Tqjg6XtOXnhh396m5R4l9I12yj24Y_sw_9mOhwTM9x5oQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='youtube.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH4beFda5Kr2KOT3F80tw530jmhewbSwC_vOwGbOrmgdkKImenYHu8IbZa4ol40UqjTgTTWnIEvAW27Sdkrv5Jf7wNBrRHxgkOPbWZ6gHjyPIq9c-I0iuzp1a4kgVzWe8ghhCB3EhI='
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=837,
#         start_index=722,
#         text='The combination of indoor art and outdoor sculptures provides both artistic stimulation and a peaceful environment.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=941,
#         start_index=868,
#         text="Parking is available via Stanford Transportation's ParkMobile App (paid)."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=1039,
#         start_index=942,
#         text='*   **Hours:** On Saturdays and Sundays, the Cantor Arts Center is open from 10:00 AM to 5:00 PM.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=2106,
#         start_index=1927,
#         text='The Palo Alto Art Center also has exhibition galleries open on Saturdays until 5:00 PM, and Sundays from 1:00 PM – 5:00 PM, which could be another free art stop if time permits.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=2483,
#         start_index=2387,
#         text='Consider **Madras Cafe** for delicious and affordable South Indian cuisine, known for its dosas.'
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHlot6r9EIxmpKbEv104Pb3JigYIQtEkwR99MuIbVAZMQyIBqR5EsVjkkVJLqaLayqx5ppOnljoElNrreYqj3WdfKSe2n0BWA0SRP15La18QxCURYH9V5axYIMU64KpN0GtPRGHyNtS4c2Sb8uZFgr2RicSHL3T_bvcyzMumEw6WKYiLXRZwt-1asWMyjR8un-8sjZSER_MeVgg1DJziwryYXvwrr3AmKYQUA==">free evening events Sunnyvale or nearby</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHFWtz7-W3fRetM1QIRIl0guiOcfUFnTIiolwrclTjsMOezUWaTpWUHtlUhbFMt2YSbkxkGiLzHqV5RKyxACSXe6CrEaTxl6rU_IQ_VgrK_G-6XOYkr8Cvwv0tds-ESoeVhkp0Uju8AABOsyNRw9x3TONp7BPRCn9_XQdrrqZRdxGlSFwk46Q_AAaxQ264jeKJVipEvnM6QBE20jCcEjujG0VpowjEkr5OTaw==">scenic parks with art near Sunnyvale CA</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF6ddVLk9XjP2bk8EB3TQOB1X79zGt-0MxnUDNOVOMf8H2KfKfbQ6geOYlVU0CKCPwCHIOHFNnYaZQRRQ0JlT0ndjV-GbU0NZKw2uqYsKheyVFb3Xn1YwO__SsFKBO1tIx1HjUHfts3vnOv95r9GCE_qs4uSf5pJixAAo3sAqpE8gBZSoJDNZWRsVUs9gwM35kV_7HUJVm6IsUgRx5IwEhvtCFw8wrCaUjua32_9ce0W0qQ0g==">free or affordable art museums near Sunnyvale CA</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHvnMjVch57ivsnq_BaMK3uhUbMRiF01TBhA5zC3MhIhw7dYtxjuh1V2g8wHaaXyG8rtqblQ3L9J0T7tAtx28vq_-oxrFknByFrTmbuDev5izCyCEujtyjqp-QOpbsr5ZzfWeuxHrVduEf__Bg0NB90ACRj1PSenpGmIA3is2JCdbFCpVOHWeR2oJKM4ZIT_U9zDaIJF8rm_l-68AI3VzUDSWmPntui">affordable lunch downtown Los Gatos</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHDSkvcoT5HJpLTbAVW48OKzlHxvDEetD7fjXRniSO2qgAJiFh1RrfxkZq4_VkImO3apAg0Hx7YiiPXARVdtfUJsQt9K6U-f_w_gBgEQk2s1T5XrHePJCS3UOUGrcbENWOiIbTkeVcyaCC36HfVpB_LSjZoepneL5-5c3lFNNUuoGag-TmVvARrj2cr0MP6h5-EdgqoX9lItlIyhE50TmyH_w==">affordable dinner Sunnyvale CA</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFT8_LuxU2ZvxesD9_vGvlrNeQShXtWzhEsOiJsyqgUG6VRPDQ4Hjh2aHW1CuAWspHp8zhunaHL0ockVm7IlZrjJ5446YzSWxI0EnkHJqkj8K2d9XwifahIQ5jjRZlmkDCC0dAm67T_Qd2T2nz3FVJPBEeGBefGzPkDYWb7WEp6ViKsuihfC8s5vlbu8ef6cgZJtXFRZ-rwXBgr1ioaYPHj4stQy4zvSPUR">San Jose Museum of Art hours admission</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFC94iOjV-aQ7DIG-3gx9sWixbScKnmVl7XnDvqKcIi4cCclbQTzUHqjv6b5h30ccSHbhxttsn4riYFGHrAJs_vXCQempEuBm4AXE2lk0zWnrwFHj0kOzrLdcyMY0d_BsOKBsbq0f8nJeyGiTNG_PK8hTGv96Oo9Sfg8N2G3GLUTpITmgz3ftXrmU2a0naxTr_KeQSxUtEXKasP25eDGlcSMQuSA191pip5JzcrOkw=">Cantor Arts Center Stanford hours admission</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEGI4tyIRWLIwiaYEPTD1qZzS7Q_gsIUSEjSUzxda7ljjnRHy2NqhNmpNuRaisKvxdEPWcdJIsyAXbT9iHLP1eMHYYZ9V3eZS2ymv4XKrwkFojmsV0IVBlNfidbbWGZzxKG5XkAwuF39QEt_FHhgsSWIPEIEPNVPxhxBtJyEtWhjZCnU-EU1xQl_5PxeFmMJgdnzxUHoWy_YRS95DnTzc7Z5228gzpspF5BTDVbZWs8sGE1">Palo Alto University Art Museum hours admission</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'free or affordable art museums near Sunnyvale CA',
#     'scenic parks with art near Sunnyvale CA',
#     'affordable lunch downtown Los Gatos',
#     'free evening events Sunnyvale or nearby',
#     'affordable dinner Sunnyvale CA',
#     <... 3 more items ...>,
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=831,
#   prompt_token_count=256,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=256
#     ),
#   ],
#   thoughts_token_count=1512,
#   tool_use_prompt_token_count=539,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=539
#     ),
#   ],
#   total_token_count=3138
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-a683b80d-204b-45bf-b078-56150cffc656' author='day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='a24fb18f-2304-42e3-9f20-e5f0b04e0e1b' timestamp=1769232798.259993
#
# --------------------------------------------------
# ✅ Final Response:
# Here's a relaxing and artsy day trip plan near Sunnyvale, CA, designed to be affordable:
#
# ---
#
# ## Relaxing & Artsy Day Trip near Sunnyvale, CA (Affordable)
#
# This itinerary focuses on enjoying art and serene environments without breaking the bank, with options for free admission and budget-friendly meals.
#
# ### 🚗 **Morning (10:00 AM - 1:00 PM): Immerse in Art at Cantor Arts Center**
#
# *   **Activity:** Begin your day with a visit to the **Cantor Arts Center at Stanford University**. This renowned museum offers free admission to its diverse collections, including art from various cultures and periods. You can explore the galleries and then take a relaxing stroll through the Rodin Sculpture Garden located outside. The combination of indoor art and outdoor sculptures provides both artistic stimulation and a peaceful environment.
# *   **Cost:** Free admission. Parking is available via Stanford Transportation's ParkMobile App (paid).
# *   **Hours:** On Saturdays and Sundays, the Cantor Arts Center is open from 10:00 AM to 5:00 PM.
# *   **Location:** 328 Lomita Drive, Stanford, CA 94305.
#
# ### 🍽️ **Lunch (1:00 PM - 2:30 PM): Affordable Bites in Palo Alto**
#
# *   **Activity:** Head to downtown Palo Alto, just a short drive from Stanford. Enjoy a casual and affordable lunch.
# *   **Suggestion:** Grab a sandwich from a local deli or enjoy a quick, budget-friendly meal at one of the many eateries. Look for places offering lunch specials or classic casual fare.
# *   **Cost:** ~$10-$20 per person.
#
# ### 🎨 **Afternoon (2:30 PM - 5:30 PM): Stroll and Discover Public Art in Palo Alto**
#
# *   **Activity:** After lunch, take a leisurely walk through downtown Palo Alto. Explore the charming streets, enjoy some window shopping, and appreciate the city's architecture. Palo Alto also has various public art installations that you might discover during your stroll, offering a relaxed continuation of your artsy theme. The Palo Alto Art Center also has exhibition galleries open on Saturdays until 5:00 PM, and Sundays from 1:00 PM – 5:00 PM, which could be another free art stop if time permits.
# *   **Cost:** Free.
#
# ### 🍜 **Evening (6:00 PM onwards): Affordable Dinner & Relaxed Evening in Sunnyvale**
#
# *   **Activity:** Head back towards Sunnyvale for an affordable and satisfying dinner.
# *   **Suggestion:** Sunnyvale offers a variety of budget-friendly dining options. Consider **Madras Cafe** for delicious and affordable South Indian cuisine, known for its dosas. Alternatively, explore the diverse range of Mexican food trucks in the area, such as **El Califas Taco Truck** or **Taqueria Pátzcuaro**, which are known for their great value and taste.
# *   **Cost:** ~$10-$20 per person.
# *   **Evening Relaxation:** After dinner, you could enjoy a peaceful evening stroll in one of Sunnyvale's parks, such as **Baylands Park** (open until sunset), or explore areas with interesting lighting if available. For a truly artsy end to the day, consider looking at the City of Sunnyvale's public art collection online, which offers self-guided tour maps for various districts.
#
# ---
#
# Enjoy your relaxing and artsy day trip!
# --------------------------------------------------

# %% [markdown]
# ---
# ## Part 2: Supercharging Agents with Custom Tools 🛠️
#
# So far, we've used the powerful built-in `GoogleSearch` tool. But the true power of agents comes from connecting them to your own logic and data sources.
#
# This is where **custom tools** come in. Let's explore three patterns for giving your agent new skills, using real-world, practical examples.

# %% [markdown]
# ### 2.1 The Simple `FunctionTool`: Calling a Real-Time Weather API
#
# The most direct way to create a tool is by writing a Python function. This is perfect for synchronous tasks like fetching data from an API.
#
# **Key Concept:** The function's **docstring** is critical. The ADK uses it as the tool's official description, which the LLM reads to understand its purpose, parameters, and when to use it.
#
# In this example, we'll create a tool that calls the **free, public U.S. National Weather Service API** to get a real-time forecast. No API key needed!

# %%
# --- Tool Definition: A function that calls a live public API ---
import requests
import json

# A simple lookup to avoid needing a separate geocoding API for this example
LOCATION_COORDINATES = {
    "sunnyvale": "37.3688,-122.0363",
    "san francisco": "37.7749,-122.4194",
    "lake tahoe": "39.0968,-120.0324"
}

def get_live_weather_forecast(location: str) -> dict:
    """Gets the current, real-time weather forecast for a specified location in the US.

    Args:
        location: The city name, e.g., "San Francisco".

    Returns:
        A dictionary containing the temperature and a detailed forecast.
    """
    print(f"🛠️ TOOL CALLED: get_live_weather_forecast(location='{location}')")

    # Find coordinates for the location
    normalized_location = location.lower()
    coords_str = None
    for key, val in LOCATION_COORDINATES.items():
        if key in normalized_location:
            coords_str = val
            break
    if not coords_str:
        return {"status": "error", "message": f"I don't have coordinates for {location}."}

    try:
        # NWS API requires 2 steps: 1. Get the forecast URL from the coordinates.
        points_url = f"https://api.weather.gov/points/{coords_str}"
        headers = {"User-Agent": "ADK Example Notebook"}
        points_response = requests.get(points_url, headers=headers)
        points_response.raise_for_status() # Raise an exception for bad status codes
        forecast_url = points_response.json()['properties']['forecast']

        # 2. Get the actual forecast from the URL.
        forecast_response = requests.get(forecast_url, headers=headers)
        forecast_response.raise_for_status()

        # Extract the relevant forecast details
        current_period = forecast_response.json()['properties']['periods'][0]
        return {
            "status": "success",
            "temperature": f"{current_period['temperature']}°{current_period['temperatureUnit']}",
            "forecast": current_period['detailedForecast']
        }
    except requests.exceptions.RequestException as e:
        return {"status": "error", "message": f"API request failed: {e}"}

# --- Agent Definition: An agent that USES the new tool ---

weather_agent = Agent(
    name="weather_aware_planner",
    model="gemini-2.5-flash",
    description="A trip planner that checks the real-time weather before making suggestions.",
    instruction="You are a cautious trip planner. Before suggesting any outdoor activities, you MUST use the `get_live_weather_forecast` tool to check conditions. Incorporate the live weather details into your recommendation.",
    tools=[get_live_weather_forecast]
)

print(f"🌦️ Agent '{weather_agent.name}' is created and can now call a live weather API!")
# Out:
# 🌦️ Agent 'weather_aware_planner' is created and can now call a live weather API!

# %%
# --- Let's test the Weather-Aware Planner ---

async def run_weather_planner_test():
    weather_session = await session_service.create_session(app_name=weather_agent.name, user_id=my_user_id)
    query = "I want to go hiking near Lake Tahoe, what's the weather like?"
    print(f"🗣️ User Query: '{query}'")
    await run_agent_query(weather_agent, query, weather_session, my_user_id)

await run_weather_planner_test()
# Out:
# 🗣️ User Query: 'I want to go hiking near Lake Tahoe, what's the weather like?'
#
# 🚀 Running query for agent: 'weather_aware_planner' in session: 'd7ebd281-0a1d-4352-acd3-f793047842b1'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'location': 'Lake Tahoe'
#         },
#         id='adk-bd5947cc-9ea8-4ddd-90cf-8654c6d28eda',
#         name='get_live_weather_forecast'
#       ),
#       thought_signature=b'\n\xc9\x02\x01r\xc8\xda|\xed,\xee\xde\xc3\xd7\xcc\x1d[\x9d\x7f\xb1b\x96\xd0\x0fU\x94B\xcb\xe2r\xe4\xb4\xf9\x08V\xa7o\x1f\xc6\xc7Ie\x05\xcdc\xa4S\x92I\x97\xe5\xa9\x0by\x02\xb7\xda\x94d8R\xea\xdd,\xc7L\xb5j\x8b_%u[;\xfe\xaf=\x98\xa6\xfd"?U&\xc5m\x088\xd2H! \xde\x97Y\xe1\x1d...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=20,
#   prompt_token_count=187,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=187
#     ),
#   ],
#   thoughts_token_count=61,
#   total_token_count=268
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-663f3788-66fe-46db-bb23-57fad1759a51' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='958cdf31-e95c-40ba-ae40-d3cafdcfd230' timestamp=1769232812.280715
# 🛠️ TOOL CALLED: get_live_weather_forecast(location='Lake Tahoe')
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-bd5947cc-9ea8-4ddd-90cf-8654c6d28eda',
#         name='get_live_weather_forecast',
#         response={
#           'forecast': 'Mostly clear, with a low around 25. East wind 5 to 10 mph.',
#           'status': 'success',
#           'temperature': '25°F'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-663f3788-66fe-46db-bb23-57fad1759a51' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='446fa43e-60d7-4b98-949c-9077c7c25043' timestamp=1769232814.122804
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="The weather near Lake Tahoe is mostly clear with a low around 25°F and an east wind of 5 to 10 mph. While it's clear, it's quite cold, so make sure to dress in warm layers and be prepared for chilly conditions if you plan to go hiking.",
#       thought_signature=b"\n\xfa\x03\x01r\xc8\xda|k\x93\x06j\x13\xba\x9c:f\x18\x10\x9c\x11\x9c\xf0\xd3z\x9b)|\xef\x91\x9e\xf8<\xbb\xecE\xe0\x07$\x9f\xd1\xb8\xef\x19\x02\x8cJ'\x85\xdd\xd4p<<\x92\xa9M\x1cu[\xbb\xd5iLy\xc6\x1c$(\xcf\xd2\xf7\xb3\xe3\x88\xb3\xc2\x93\xe4\xafS\xaf\xae\x1bc\x8c\xe7\xb0\xb1R\xcc\xe3\xd9\x0c\x80q5...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=63,
#   prompt_token_count=260,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=260
#     ),
#   ],
#   thoughts_token_count=112,
#   total_token_count=435
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-663f3788-66fe-46db-bb23-57fad1759a51' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='dab11618-bbe0-4cc5-b9e0-ee05a841dd62' timestamp=1769232814.125772
#
# --------------------------------------------------
# ✅ Final Response:
# The weather near Lake Tahoe is mostly clear with a low around 25°F and an east wind of 5 to 10 mph. While it's clear, it's quite cold, so make sure to dress in warm layers and be prepared for chilly conditions if you plan to go hiking.
# --------------------------------------------------

# %% [markdown]
# ## 2.2 The Agent-as-a-Tool: Consulting a Specialist 🧑‍🍳
#
# Why build one agent that does everything when you can build a **team of specialist agents?** The **Agent-as-a-Tool** pattern allows one agent to delegate a task to another agent.
#
# **Key Concept:** This is different from a sub-agent. When Agent A calls Agent B as a tool, Agent B's response is passed **back to Agent A**. Agent A then uses that information to form its own final response to the user. It's a powerful way to compose complex behaviors from simpler, focused, and reusable agents.

# %% [markdown]
# ### How It Works
#
# Our top-level agent, the `trip_data_concierge_agent`, acts as the **Orchestrator**. It has two tools at its disposal:
#
# 1.  `call_db_agent`: A function that internally calls our `db_agent` to fetch raw data.
# 2.  `call_concierge_agent`: A function that calls the `concierge_agent`.
#
# The `concierge_agent` itself has a tool: the `food_critic_agent`.
#
# The flow for a complex query is:
#
# 1.  **User** asks the `trip_data_concierge_agent` for a hotel and a nearby restaurant.
# 2.  The **Orchestrator** first calls `call_db_agent` to get hotel data.
# 3.  The data is saved in `tool_context.state`.
# 4.  The **Orchestrator** then calls `call_concierge_agent`, which retrieves the hotel data from the context.
# 5.  The `concierge_agent` receives the request and decides it needs to use its own tool, the `food_critic_agent`.
# 6.  The `food_critic_agent` provides a witty recommendation.
# 7.  The `concierge_agent` gets the critic's response and politely formats it.
# 8.  This final, polished response is returned to the **Orchestrator**, which presents it to the user.

# %% [markdown]
#                          +-----------------------------------------------------------+
#                          |              🧭 Trip Data Concierge Agent                 |
#                          |-----------------------------------------------------------|
#                          |  Model: gemini-2.5-flash                                  |
#                          |  Description:                                             |
#                          |   Orchestrates database query and travel recommendation  |
#                          |-----------------------------------------------------------|
#                          |  🔧 Tools:                                                |
#                          |   1. call_db_agent                                        |
#                          |   2. call_concierge_agent                                 |
#                          +-----------------------------------------------------------+
#                                       /                                \
#                                      /                                  \
#                                     ▼                                    ▼
#         +-------------------------------------------+    +---------------------------------------------+
#         |            🔧 Tool: call_db_agent         |    |         🔧 Tool: call_concierge_agent        |
#         |-------------------------------------------|    |---------------------------------------------|
#         | Calls: db_agent                           |    | Calls: concierge_agent                       |
#         |                                           |    | Uses data from db_agent for recommendations |
#         +-------------------------------------------+    +---------------------------------------------+
#                                 |                                          |
#                                 ▼                                          ▼
#        +--------------------------------------------+   +------------------------------------------------+
#        |              📦 db_agent                   |   |             🤵 concierge_agent                  |
#        |--------------------------------------------|   |------------------------------------------------|
#        | Model: gemini-2.5-flash                    |   | Model: gemini-2.5-flash                         |
#        | Role: Return mock JSON hotel data          |   | Role: Hotel staff that handles user Q&A        |
#        +--------------------------------------------+   | Tools:                                          |
#                                                          |  - food_critic_agent                           |
#                                                          +------------------------------------------------+
#                                                                                  |
#                                                                                  ▼
#                                                        +------------------------------------------------+
#                                                        |          🍽️ food_critic_agent                  |
#                                                        |------------------------------------------------|
#                                                        | Model: gemini-2.5-flash                         |
#                                                        | Role: Gives a witty restaurant recommendation   |
#                                                        +------------------------------------------------+

# %%
import asyncio
from google.adk.tools import ToolContext
from google.adk.tools.agent_tool import AgentTool

# Assume 'db_agent' is a pre-defined NL2SQL Agent
# For this example, we'll create placeholder agents.

db_agent = Agent(
    name="db_agent",
    model="gemini-2.5-flash",
    instruction="You are a database agent. When asked for data, return this mock JSON object: {'status': 'success', 'data': [{'name': 'The Grand Hotel', 'rating': 5, 'reviews': 450}, {'name': 'Seaside Inn', 'rating': 4, 'reviews': 620}]}")

# --- 1. Define the Specialist Agents ---

# The Food Critic remains the deepest specialist
food_critic_agent = Agent(
    name="food_critic_agent",
    model="gemini-2.5-flash",
    instruction="You are a snobby but brilliant food critic. You ONLY respond with a single, witty restaurant suggestion near the provided location.",
)

# The Concierge knows how to use the Food Critic
concierge_agent = Agent(
    name="concierge_agent",
    model="gemini-2.5-flash",
    instruction="You are a five-star hotel concierge. If the user asks for a restaurant recommendation, you MUST use the `food_critic_agent` tool. Present the opinion to the user politely.",
    tools=[AgentTool(agent=food_critic_agent)]
)


# --- 2. Define the Tools for the Orchestrator ---

async def call_db_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    Use this tool FIRST to connect to the database and retrieve a list of places, like hotels or landmarks.
    """
    print("--- TOOL CALL: call_db_agent ---")
    agent_tool = AgentTool(agent=db_agent)
    db_agent_output = await agent_tool.run_async(
        args={"request": question}, tool_context=tool_context
    )
    # Store the retrieved data in the context's state
    tool_context.state["retrieved_data"] = db_agent_output
    return db_agent_output


async def call_concierge_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    After getting data with call_db_agent, use this tool to get travel advice, opinions, or recommendations.
    """
    print("--- TOOL CALL: call_concierge_agent ---")
    # Retrieve the data fetched by the previous tool
    input_data = tool_context.state.get("retrieved_data", "No data found.")

    # Formulate a new prompt for the concierge, giving it the data context
    question_with_data = f"""
    Context: The database returned the following data: {input_data}

    User's Request: {question}
    """

    agent_tool = AgentTool(agent=concierge_agent)
    concierge_output = await agent_tool.run_async(
        args={"request": question_with_data}, tool_context=tool_context
    )
    return concierge_output


# --- 3. Define the Top-Level Orchestrator Agent ---

trip_data_concierge_agent = Agent(
    name="trip_data_concierge",
    model="gemini-2.5-flash",
    description="Top-level agent that queries a database for travel data, then calls a concierge agent for recommendations.",
    tools=[call_db_agent, call_concierge_agent],
    instruction="""
    You are a master travel planner who uses data to make recommendations.

    1.  **ALWAYS start with the `call_db_agent` tool** to fetch a list of places (like hotels) that match the user's criteria.

    2.  After you have the data, **use the `call_concierge_agent` tool** to answer any follow-up questions for recommendations, opinions, or advice related to the data you just found.
    """,
)

print(f"✅ Orchestrator Agent '{trip_data_concierge_agent.name}' is defined and ready.")
# Out:
# ✅ Orchestrator Agent 'trip_data_concierge' is defined and ready.

# %%
# --- Let's test the Trip Data Concierge Agent ---

async def run_trip_data_concierge():
    """
    Sets up a session and runs a query against the top-level
    trip_data_concierge_agent.
    """
    # Create a new, single-use session for this query
    concierge_session = await session_service.create_session(
        app_name=trip_data_concierge_agent.name,
        user_id=my_user_id
    )

    # This query is specifically designed to trigger the full two-step process:
    # 1. Get data from the db_agent.
    # 2. Get a recommendation from the concierge_agent based on that data.
    query = "Find the top-rated hotels in San Francisco from the database, then suggest a dinner spot near the one with the most reviews."
    print(f"🗣️ User Query: '{query}'")

    # We call our existing helper function with the top-level orchestrator agent
    await run_agent_query(trip_data_concierge_agent, query, concierge_session, my_user_id)

# Run the test
await run_trip_data_concierge()
# Out:
# 🗣️ User Query: 'Find the top-rated hotels in San Francisco from the database, then suggest a dinner spot near the one with the most reviews.'
#
# 🚀 Running query for agent: 'trip_data_concierge' in session: '3d45d82f-1ae7-41b9-b706-ca6376c857fe'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'top-rated hotels in San Francisco'
#         },
#         id='adk-b9fe3bfe-f333-4908-965b-2be00a4f32b2',
#         name='call_db_agent'
#       ),
#       thought_signature=b'\n\x8d\x03\x01r\xc8\xda|IL\xe4U\x90\x0cs\x9b\xbe\xdf\x113\xf3\xcb\xda\xa4;1\xdbBxF\xa5\xa1\xdd\x89\xfco\x04\xa7\x16C\xd4v\xcf2\xf9\xf1\xaa\x18\xdd\x92t\x14\xaf\x85\xc9\xcd\xb1N\xe2\xdd\x12\x06\xc2\xa9q\xce\x12\xec\xd8\x0erj\x99\xba\x11\x9b~t\xe2 \xdb2\xe2\xa1\xb1\x0bP\x85Ew8i*C\xa8\xb4b...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=23,
#   prompt_token_count=293,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=293
#     ),
#   ],
#   thoughts_token_count=85,
#   total_token_count=401
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-352187bc-ff92-4a60-9bb1-dcce7ae96d5e' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='63907a9a-e467-42e8-bafa-fbbefb7dca90' timestamp=1769232815.815497
# --- TOOL CALL: call_db_agent ---
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-b9fe3bfe-f333-4908-965b-2be00a4f32b2',
#         name='call_db_agent',
#         response={
#           'result': """```json
# {
#   "status": "success",
#   "data": [
#     {
#       "name": "The Grand Hotel",
#       "rating": 5,
#       "reviews": 450
#     },
#     {
#       "name": "Seaside Inn",
#       "rating": 4,
#       "reviews": 620
#     }
#   ]
# }
# ```"""
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-352187bc-ff92-4a60-9bb1-dcce7ae96d5e' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={'retrieved_data': '```json\n{\n  "status": "success",\n  "data": [\n    {\n      "name": "The Grand Hotel",\n      "rating": 5,\n      "reviews": 450\n    },\n    {\n      "name": "Seaside Inn",\n      "rating": 4,\n      "reviews": 620\n    }\n  ]\n}\n```'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='1925ae55-4ce2-4bee-8c16-7c381530e42f' timestamp=1769232818.450041
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'Suggest a dinner spot near Seaside Inn in San Francisco.'
#         },
#         id='adk-c6a071b3-efbb-4984-bc1c-bde325df6538',
#         name='call_concierge_agent'
#       ),
#       thought_signature=b'\n\x88\x03\x01r\xc8\xda|\xc7\xa4Y>\x87=\x0e/\xd6W\xe0\xaf\xf1G\x94\x08\n\xa1x\xfd1\x1a(\xa6\xd8\x1e\xd0\xac\xfc\xe8\x8a\xe0\xbb\xab\x87@$\xf0B\x0e\x91S\x16\xd7\x14.H$\x8f"\x8c\x042\xbb\xf9\x9aG\xfc\xa4Zrp<\xb5V\xf9\xee\x04\x82$Y\xb8"[\x06\xe8.w\x13=/<[\xab\xe2)\xd0\x7fN...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=27,
#   prompt_token_count=429,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=429
#     ),
#   ],
#   thoughts_token_count=98,
#   total_token_count=554
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-352187bc-ff92-4a60-9bb1-dcce7ae96d5e' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='8903a726-a450-4c55-b829-c9e9689fa942' timestamp=1769232818.453092
# --- TOOL CALL: call_concierge_agent ---
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-c6a071b3-efbb-4984-bc1c-bde325df6538',
#         name='call_concierge_agent',
#         response={
#           'result': 'Ah, a discerning diner! For a truly exceptional experience near the Seaside Inn, I must highly recommend Gary Danko. It is, without question, a culinary destination for those who appreciate fine dining and impeccable service.'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-352187bc-ff92-4a60-9bb1-dcce7ae96d5e' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='5847823c-88fe-41a2-aa64-c2551212ecc6' timestamp=1769232827.847453
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Ah, a discerning diner! For a truly exceptional experience near the Seaside Inn, I must highly recommend Gary Danko. It is, without question, a culinary destination for those who appreciate fine dining and impeccable service.',
#       thought_signature=b'\n\x88\x02\x01r\xc8\xda|\xe9\x18\xd5\xf5\t!\x10\x8bJ\x1a\x92C\\\x8c\xc5\x7fi\xd9\x8d\xdc\xf4\xd41\xbca\xbf\xden\x1d\xb74\x03\xff\xdf\xe6!\xb9\xdb\xe1\x15^\x1e(G\x068\xd3\r\t~\xe8\xed\x19\xab*h\x11\xd5\x01K!%|\x1c}[\xb4;G\x01\xd4\xf0\x9e\x1d\x89\xdeQ\x8f\x1e\xe7u\x8f\xc3\xa5\xc6\xdd\x17m\xd0...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=43,
#   prompt_token_count=516,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=516
#     ),
#   ],
#   thoughts_token_count=56,
#   total_token_count=615
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-352187bc-ff92-4a60-9bb1-dcce7ae96d5e' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='18905137-4dde-4ddd-bc2e-f041360d77aa' timestamp=1769232827.849601
#
# --------------------------------------------------
# ✅ Final Response:
# Ah, a discerning diner! For a truly exceptional experience near the Seaside Inn, I must highly recommend Gary Danko. It is, without question, a culinary destination for those who appreciate fine dining and impeccable service.
# --------------------------------------------------

# %% [markdown]
# ---
# ## Part 3: Agent with a Memory - The Adaptive Planner 🗺️
#
# Now, let's see an agent that not only **remembers** but also **adapts**. We'll challenge the `multi_day_trip_agent` to re-plan part of its itinerary based on our feedback. This is a much more realistic test of conversational AI.

# %% [markdown]
# ```
# +-----------------------------------------------------+
# |         Adaptive Multi-Day Trip Agent 🗺️           |
# |-----------------------------------------------------|
# |  Model: gemini-2.5-flash                            |
# |  Description:                                       |
# |   Builds multi-day travel itineraries step-by-step, |
# |   remembers previous days, adapts to feedback       |
# |-----------------------------------------------------|
# |  🔧 Tools:                                          |
# |   - Google Search                                   |
# |-----------------------------------------------------|
# |  🧠 Capabilities:                                   |
# |   - Memory of past conversation & preferences       |
# |   - Progressive planning (1 day at a time)          |
# |   - Adapts to user feedback                         |
# |   - Ensures activity variety across days            |
# +-----------------------------------------------------+
#
#             ▲
#             |
#     +---------------------------+
#     |     User Interaction      |
#     |---------------------------|
#     | - Destination             |
#     | - Trip duration           |
#     | - Interests & feedback    |
#     +---------------------------+
#
#             |
#             ▼
#
# +-----------------------------------------------------+
# |        Day-by-Day Itinerary Generation              |
# |-----------------------------------------------------|
# |  🗓️ Day N Output (Markdown format):                 |
# |   - Morning / Afternoon / Evening activities        |
# |   - Personalized & context-aware                    |
# |   - Changes accepted, feedback acknowledged         |
# +-----------------------------------------------------+
#
#             |
#             ▼
#
# +-----------------------------------------------------+
# |        Next Day Planning Triggered 🚀               |
# |-----------------------------------------------------|
# | - Builds on prior days                              |
# | - Avoids repetition                                 |
# | - Asks user for confirmation before proceeding      |
# +-----------------------------------------------------+
# ```

# %%
# --- Agent Definition: The Adaptive Planner ---

def create_multi_day_trip_agent():
    """Create the Progressive Multi-Day Trip Planner agent"""
    return Agent(
        name="multi_day_trip_agent",
        model="gemini-2.5-flash",
        description="Agent that progressively plans a multi-day trip, remembering previous days and adapting to user feedback.",
        instruction="""
        You are the "Adaptive Trip Planner" 🗺️ - an AI assistant that builds multi-day travel itineraries step-by-step.

        Your Defining Feature:
        You have short-term memory. You MUST refer back to our conversation to understand the trip's context, what has already been planned, and the user's preferences. If the user asks for a change, you must adapt the plan while keeping the unchanged parts consistent.

        Your Mission:
        1.  **Initiate**: Start by asking for the destination, trip duration, and interests.
        2.  **Plan Progressively**: Plan ONLY ONE DAY at a time. After presenting a plan, ask for confirmation.
        3.  **Handle Feedback**: If a user dislikes a suggestion (e.g., "I don't like museums"), acknowledge their feedback, and provide a *new, alternative* suggestion for that time slot that still fits the overall theme.
        4.  **Maintain Context**: For each new day, ensure the activities are unique and build logically on the previous days. Do not suggest the same things repeatedly.
        5.  **Final Output**: Return each day's itinerary in MARKDOWN format.
        """,
        tools=[google_search]
    )

multi_day_agent = create_multi_day_trip_agent()
print(f"🗺️ Agent '{multi_day_agent.name}' is created and ready to plan and adapt!")
# Out:
# 🗺️ Agent 'multi_day_trip_agent' is created and ready to plan and adapt!

# %% [markdown]
# ### Scenario 3a: Agent WITH Memory (Using a SINGLE Session) ✅
#
# First, let's see the correct way to do it. We will use the **exact same `trip_session` object** for the entire conversation. Watch how the agent remembers the context from Turn 1 to correctly handle the requests in Turn 2 and 3.

# %%
# --- Scenario 2: Testing Adaptation and Memory ---

async def run_adaptive_memory_demonstration():
    print("### 🧠 DEMO 2: AGENT THAT ADAPTS (SAME SESSION) ###")

    # Create ONE session that we will reuse for the whole conversation
    trip_session = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"Created a single session for our trip: {trip_session.id}")

    # --- Turn 1: The user initiates the trip ---
    query1 = "Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food."
    print(f"\n🗣️ User (Turn 1): '{query1}'")
    await run_agent_query(multi_day_agent, query1, trip_session, my_user_id)

    # --- Turn 2: The user gives FEEDBACK and asks for a CHANGE ---
    # We use the EXACT SAME `trip_session` object!
    query2 = "That sounds pretty good, but I'm not a huge fan of castles. Can you replace the morning activity for Day 1 with something else historical?"
    print(f"\n🗣️ User (Turn 2 - Feedback): '{query2}'")
    await run_agent_query(multi_day_agent, query2, trip_session, my_user_id)

    # --- Turn 3: The user confirms and asks to continue ---
    query3 = "Yes, the new plan for Day 1 is perfect! Please plan Day 2 now, keeping the food theme in mind."
    print(f"\n🗣️ User (Turn 3 - Confirmation): '{query3}'")
    await run_agent_query(multi_day_agent, query3, trip_session, my_user_id)

await run_adaptive_memory_demonstration()
# Out:
# ### 🧠 DEMO 2: AGENT THAT ADAPTS (SAME SESSION) ###
# Created a single session for our trip: 4ce4d06c-59e3-4737-9539-2801e2798b11
#
# 🗣️ User (Turn 1): 'Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: '4ce4d06c-59e3-4737-9539-2801e2798b11'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Okay, fantastic! Lisbon is a wonderful choice with a rich history and incredible food.
#
# Let's start planning Day 1. How does this sound for your first day in Lisbon, focusing on historic sites and local cuisine?
#
# ### Day 1: Historic Alfama & Baixa Delights
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Alfama District**
#     *   Begin your day by getting lost in the winding, narrow streets of Alfama, Lisbon's oldest district.
#     *   Visit **Lisbon Cathedral (Sé de Lisboa)**, a majestic Romanesque cathedral with a fascinating history.
#     *   Wander up to **Miradouro das Portas do Sol** and **Miradouro de Santa Luzia** for breathtaking panoramic views of the Alfama rooftops and the Tagus River.
#     *   Explore **São Jorge Castle (Castelo de São Jorge)**, a historic Moorish castle offering stunning views and a glimpse into Lisbon's past.
#
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Flavors**
#     *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a small, informal restaurant) serving dishes like *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or *Sardinhas Assadas* (grilled sardines, especially if you're there in warmer months).
#
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa & Praça do Comércio**
#     *   Descend from Alfama into the grid-like streets of the Baixa district, rebuilt after the 1755 earthquake.
#     *   Walk along **Rua Augusta**, a bustling pedestrian street, and admire the **Arco da Rua Augusta**.
#     *   Explore **Praça do Comércio**, one of Europe's largest and most magnificent squares, right on the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner & Fado Experience**
#     *   Enjoy dinner in the Baixa or Chiado area.
#     *   Consider experiencing a traditional **Fado show** in Alfama or Bairro Alto, often paired with dinner, for an authentic taste of Portuguese culture and music.
#
# What do you think of this plan for Day 1? Would you like any changes or different suggestions?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=514,
#   prompt_token_count=331,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=331
#     ),
#   ],
#   thoughts_token_count=38,
#   total_token_count=883
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-81549bf8-9ba6-4818-87c3-3fbd6d989404' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='376138f7-b525-4ed5-819a-5fd352a28c78' timestamp=1769232828.96232
#
# --------------------------------------------------
# ✅ Final Response:
# Okay, fantastic! Lisbon is a wonderful choice with a rich history and incredible food.
#
# Let's start planning Day 1. How does this sound for your first day in Lisbon, focusing on historic sites and local cuisine?
#
# ### Day 1: Historic Alfama & Baixa Delights
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Alfama District**
#     *   Begin your day by getting lost in the winding, narrow streets of Alfama, Lisbon's oldest district.
#     *   Visit **Lisbon Cathedral (Sé de Lisboa)**, a majestic Romanesque cathedral with a fascinating history.
#     *   Wander up to **Miradouro das Portas do Sol** and **Miradouro de Santa Luzia** for breathtaking panoramic views of the Alfama rooftops and the Tagus River.
#     *   Explore **São Jorge Castle (Castelo de São Jorge)**, a historic Moorish castle offering stunning views and a glimpse into Lisbon's past.
#
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Flavors**
#     *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a small, informal restaurant) serving dishes like *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or *Sardinhas Assadas* (grilled sardines, especially if you're there in warmer months).
#
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa & Praça do Comércio**
#     *   Descend from Alfama into the grid-like streets of the Baixa district, rebuilt after the 1755 earthquake.
#     *   Walk along **Rua Augusta**, a bustling pedestrian street, and admire the **Arco da Rua Augusta**.
#     *   Explore **Praça do Comércio**, one of Europe's largest and most magnificent squares, right on the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner & Fado Experience**
#     *   Enjoy dinner in the Baixa or Chiado area.
#     *   Consider experiencing a traditional **Fado show** in Alfama or Bairro Alto, often paired with dinner, for an authentic taste of Portuguese culture and music.
#
# What do you think of this plan for Day 1? Would you like any changes or different suggestions?
# --------------------------------------------------
#
#
# 🗣️ User (Turn 2 - Feedback): 'That sounds pretty good, but I'm not a huge fan of castles. Can you replace the morning activity for Day 1 with something else historical?'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: '4ce4d06c-59e3-4737-9539-2801e2798b11'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Okay, I understand! No problem, we can definitely swap out the castle for another historical gem.
#
# How about this revised morning plan for Day 1?
#
# ### Day 1: Historic Alfama & Baixa Delights (Revised Morning)
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Alfama District & National Pantheon**
#     *   Begin your day by getting lost in the winding, narrow streets of Alfama, Lisbon's oldest district.
#     *   Visit **Lisbon Cathedral (Sé de Lisboa)**, a majestic Romanesque cathedral with a fascinating history.
#     *   Wander up to **Miradouro das Portas do Sol** and **Miradouro de Santa Luzia** for breathtaking panoramic views of the Alfama rooftops and the Tagus River.
#     *   Instead of the castle, we'll visit the **National Pantheon (Panteão Nacional)**. This impressive Baroque building, originally the Church of Santa Engrácia, houses the tombs of many important Portuguese historical figures. Its dome offers incredible 360-degree views of the city and the river.
#
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Flavors**
#     *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a small, informal restaurant) serving dishes like *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or *Sardinhas Assadas* (grilled sardines, especially if you're there in warmer months).
#
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa & Praça do Comércio**
#     *   Descend from Alfama into the grid-like streets of the Baixa district, rebuilt after the 1755 earthquake.
#     *   Walk along **Rua Augusta**, a bustling pedestrian street, and admire the **Arco da Rua Augusta**.
#     *   Explore **Praça do Comércio**, one of Europe's largest and most magnificent squares, right on the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner & Fado Experience**
#     *   Enjoy dinner in the Baixa or Chiado area.
#     *   Consider experiencing a traditional **Fado show** in Alfama or Bairro Alto, often paired with dinner, for an authentic taste of Portuguese culture and music.
#
# How does the National Pantheon sound as a historical replacement for the castle? Does this revised Day 1 work for you?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=542,
#   prompt_token_count=878,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=878
#     ),
#   ],
#   thoughts_token_count=191,
#   total_token_count=1611
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-f7f6d147-4829-4ad7-93a8-502496619fd0' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='abb5b123-36bb-4a60-8f26-d22f4c6832ce' timestamp=1769232832.570778
#
# --------------------------------------------------
# ✅ Final Response:
# Okay, I understand! No problem, we can definitely swap out the castle for another historical gem.
#
# How about this revised morning plan for Day 1?
#
# ### Day 1: Historic Alfama & Baixa Delights (Revised Morning)
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Alfama District & National Pantheon**
#     *   Begin your day by getting lost in the winding, narrow streets of Alfama, Lisbon's oldest district.
#     *   Visit **Lisbon Cathedral (Sé de Lisboa)**, a majestic Romanesque cathedral with a fascinating history.
#     *   Wander up to **Miradouro das Portas do Sol** and **Miradouro de Santa Luzia** for breathtaking panoramic views of the Alfama rooftops and the Tagus River.
#     *   Instead of the castle, we'll visit the **National Pantheon (Panteão Nacional)**. This impressive Baroque building, originally the Church of Santa Engrácia, houses the tombs of many important Portuguese historical figures. Its dome offers incredible 360-degree views of the city and the river.
#
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Flavors**
#     *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a small, informal restaurant) serving dishes like *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or *Sardinhas Assadas* (grilled sardines, especially if you're there in warmer months).
#
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa & Praça do Comércio**
#     *   Descend from Alfama into the grid-like streets of the Baixa district, rebuilt after the 1755 earthquake.
#     *   Walk along **Rua Augusta**, a bustling pedestrian street, and admire the **Arco da Rua Augusta**.
#     *   Explore **Praça do Comércio**, one of Europe's largest and most magnificent squares, right on the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner & Fado Experience**
#     *   Enjoy dinner in the Baixa or Chiado area.
#     *   Consider experiencing a traditional **Fado show** in Alfama or Bairro Alto, often paired with dinner, for an authentic taste of Portuguese culture and music.
#
# How does the National Pantheon sound as a historical replacement for the castle? Does this revised Day 1 work for you?
# --------------------------------------------------
#
#
# 🗣️ User (Turn 3 - Confirmation): 'Yes, the new plan for Day 1 is perfect! Please plan Day 2 now, keeping the food theme in mind.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: '4ce4d06c-59e3-4737-9539-2801e2798b11'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Great! I'm glad Day 1 is perfect. Let's dive into Day 2, focusing on more historical exploration and, of course, delicious food experiences.
#
# Here's a plan for your second day in Lisbon:
#
# ### Day 2: Belém's Maritime History & Food Exploration
#
# *   **Morning (9:30 AM - 1:00 PM): Discover Belém's Maritime Heritage**
#     *   Start your day by heading to the historic Belém district, a testament to Portugal's Age of Discoveries. You can reach it easily by tram or taxi.
#     *   Visit the magnificent **Jerónimos Monastery (Mosteiro dos Jerónimos)**, a UNESCO World Heritage site and a prime example of Manueline architecture. This impressive monastery was commissioned by King Manuel I in the early 1500s and served as a place for monks to pray for the king and offer spiritual assistance to sailors departing on long journeys.
#     *   Explore its intricate church and serene cloisters.
#     *   Walk along the Tagus riverfront to see the iconic **Belém Tower (Torre de Belém)**, a 16th-century fortification that once guarded the entrance to Lisbon's harbor.
#     *   Also, admire the grand **Monument to the Discoveries (Padrão dos Descobrimentos)**, which celebrates Portugal's explorers and their contributions to maritime history.
#
# *   **Lunch (1:00 PM - 2:30 PM): Original Pastéis de Belém**
#     *   A trip to Belém isn't complete without a visit to **Pastéis de Belém**, the legendary bakery where the original *Pastéis de Nata* (custard tarts) have been made since 1837 using a secret, ancient recipe from the Jerónimos Monastery. Enjoy them warm, dusted with cinnamon and powdered sugar.
#     *   For a more substantial lunch, you can find a local restaurant in Belém offering fresh seafood or other Portuguese specialties.
#
# *   **Afternoon (2:30 PM - 6:00 PM): Time Out Market & Riverside Atmosphere**
#     *   Head back towards the city center to the **Time Out Market (Mercado da Ribeira)** near Cais do Sodré. This vibrant food hall, which opened in 2014, features a wide array of stalls from top Portuguese chefs and traditional eateries, offering a fantastic opportunity to sample various local delicacies all in one place.
#     *   Afterward, you could take a leisurely stroll along the Cais do Sodré / Ribeira das Naus riverfront, enjoying the views of the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner in Chiado or Bairro Alto**
#     *   Explore the elegant Chiado district, known for its historic cafés and theaters.
#     *   Enjoy your final dinner in Lisbon in either Chiado (for a more upscale experience) or the lively Bairro Alto (for traditional restaurants and a vibrant atmosphere). Consider trying another Portuguese classic like *Arroz de Marisco* (seafood rice) or *Polvo à Lagareiro* (roasted octopus).
#
# What do you think of this plan for Day 2? Does it capture your interests for historical sites and great local food?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='unesco.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHH1qPxGsoVO51a_TTlTmMzq6OKFd67EAxqyGJYHbO6dO33sxFOuILurUBdCqhUxQAVaEcjbXsrxmX-kEFMQxQl63q2PQM9aSyRMWvgO_ngJoQNr2bcpxIa_VrmZsE='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='museusemonumentos.pt',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHIySR5mjHCheYLqe7kMZsAHcXpbyuoytOKtMoLDfdQYzlzE4q0QNzrTyTDP3AHRdDgfwfqfUElZUkNE8pTR_9khk6km-IzWKXj9T2ixzxkd0NWavXcsinZ-enqX4oGlcTcSKUNnxMninJxq5JNkQ43TPSknBFk7sAU-KIiLTTftgdaEXD_sIBP0Ld8cXH6JwuZhL93J6KQb0zpNgddU3BYRg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='manorhouses.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGTuX8RriOImckq62vAQz5k8_flm6FMMg05FIofYVLuwz-5tJ8HaPRk7kAsQTjRUzlbb3xaJSLzWdvd6-f8tomuDB1XXiQoYGJo5qh_96ci6JF71lKi80pg9mfar_rXR1Xl4kuAkmva4dg='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='veryhungrynomads.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEDXIuKH4b7UhBQ2KG_vAPqyuFvAA0xb6Hf5-7SPoI08eiGxL0UW7PuUwu_YSRa2y2Z4Fylqwb96LwV_EReN768tVdSZQKm1iWBzNJc4Ljz-1fr7F-Bm8tF4_OkjIAjsd5nWuGkrzPEnQs2WDSzKqiGjfzle6ST0sKV_S1kRY-u0ZJ7'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='pasteisdebelem.pt',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGUsDoRMuN6dU2NSVBpRgjssOMGlWUiRCuU1x4vkEBkJSMz4G936pmIohYhwFKGelo7Z0X9K108tRA_RnRWqfIOao8R0EXF6JFsiQR95CNaaf8tF8xavkQOlGZXh2fV6Q=='
#       )
#     ),
#     <... 8 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=831,
#         start_index=630,
#         text='This impressive monastery was commissioned by King Manuel I in the early 1500s and served as a place for monks to pray for the king and offer spiritual assistance to sailors departing on long journeys.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         1,
#       ],
#       segment=Segment(
#         end_index=890,
#         start_index=836,
#         text='*   Explore its intricate church and serene cloisters.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         0,
#       ],
#       segment=Segment(
#         end_index=1064,
#         start_index=895,
#         text="*   Walk along the Tagus riverfront to see the iconic **Belém Tower (Torre de Belém)**, a 16th-century fortification that once guarded the entrance to Lisbon's harbor."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=1240,
#         start_index=1069,
#         text="*   Also, admire the grand **Monument to the Discoveries (Padrão dos Descobrimentos)**, which celebrates Portugal's explorers and their contributions to maritime history."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#         5,
#         6,
#         7,
#       ],
#       segment=Segment(
#         end_index=1550,
#         start_index=1242,
#         text="""*   **Lunch (1:00 PM - 2:30 PM): Original Pastéis de Belém**
#     *   A trip to Belém isn't complete without a visit to **Pastéis de Belém**, the legendary bakery where the original *Pastéis de Nata* (custard tarts) have been made since 1837 using a secret, ancient recipe from the Jerónimos Monastery."""
#       )
#     ),
#     <... 2 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEyB_xYB36KEgzuW8_kzSRp0VZgM6JrUY2IckK2KysO2YAGfmHe6cX_-SJ-CytgdCsum8GkoVHmGkTojhY0hRF_iPRdLgA-KvhRbzxUVZYln2YHmKOgdMBMIqjbuthu3iSef3L_MoWvARpuHyEsJSptOX4SgOWI6pQ3K33QU7GkYvBoaZqlVjqKSW6j5eSbjX3koTrun8Etrw==">Time Out Market Lisbon</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFFRFBt2Q06BZX2JDSlu_hAnGemjmqZIFaEVjO6i-MV9CQvQ-GEy6U0Vn4nO_OjpRd5DPrRIcX4IdG0ati2wS05UI227oItCxGg9oeJvLSfnlppSFtxmQz1ADvBmMMA9KP3PUUKqk4hXWLSvPyEKk8hbYEhNPc7jxtn92zj2oqGGh8J5yN9mXsFOXbZHnRB1fIeLyLDvTmpvagumViGllMqjR6niA==">Pastéis de Belém history</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF0_lX6d_ImI8C2zO1CLbPk5VLTCy_AFzUu9OCiOH_sLe7HOas64dZPz6TcNP2GJQGVC1EUCffdDwcLAueOg_uLPDCkIpeXa8gJ1UMg7GX6m8ba8IcW0LZmxZKefo8xGoAbtWROjCndhz25tovsOUb2KaUDmfWaWXRVyB-kjDQEBOyer4fiUPNaYeBiMX-c5CO0GKk-sN6U1s-togI2Y13M9OEmN4wgl-sQQLJB">Lisbon Day 2 itinerary historic sites food</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG9vtr_a7-2m668raRWwD3DQk_u8PRmxBLALnWHfRQCiybUUMZrWh-rnAVQgYYj5KX_NVlY-Z_vNYd7j5ZS6nVUcLM711PBvyMXUV7M599cymTwl0jwdrSfBV0wtPigH4Ua2e-XzGeZVFJ6LyTZ_yDYmjhwoOcPcDnwJ5x4cppl4B4quq07uGZKMtgeNkaKvvWYLgTrvhfLQ0PuvxGf2Ol5eg==">Jerónimos Monastery UNESCO</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Lisbon Day 2 itinerary historic sites food',
#     'Jerónimos Monastery UNESCO',
#     'Pastéis de Belém history',
#     'Time Out Market Lisbon',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=742,
#   prompt_token_count=1448,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1448
#     ),
#   ],
#   thoughts_token_count=777,
#   tool_use_prompt_token_count=2266,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2266
#     ),
#   ],
#   total_token_count=5233
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-3817f31a-6005-4eee-8979-9f665e433707' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='087454ae-6d10-4ea6-babd-dc58fcddc6c5' timestamp=1769232836.737221
#
# --------------------------------------------------
# ✅ Final Response:
# Great! I'm glad Day 1 is perfect. Let's dive into Day 2, focusing on more historical exploration and, of course, delicious food experiences.
#
# Here's a plan for your second day in Lisbon:
#
# ### Day 2: Belém's Maritime History & Food Exploration
#
# *   **Morning (9:30 AM - 1:00 PM): Discover Belém's Maritime Heritage**
#     *   Start your day by heading to the historic Belém district, a testament to Portugal's Age of Discoveries. You can reach it easily by tram or taxi.
#     *   Visit the magnificent **Jerónimos Monastery (Mosteiro dos Jerónimos)**, a UNESCO World Heritage site and a prime example of Manueline architecture. This impressive monastery was commissioned by King Manuel I in the early 1500s and served as a place for monks to pray for the king and offer spiritual assistance to sailors departing on long journeys.
#     *   Explore its intricate church and serene cloisters.
#     *   Walk along the Tagus riverfront to see the iconic **Belém Tower (Torre de Belém)**, a 16th-century fortification that once guarded the entrance to Lisbon's harbor.
#     *   Also, admire the grand **Monument to the Discoveries (Padrão dos Descobrimentos)**, which celebrates Portugal's explorers and their contributions to maritime history.
#
# *   **Lunch (1:00 PM - 2:30 PM): Original Pastéis de Belém**
#     *   A trip to Belém isn't complete without a visit to **Pastéis de Belém**, the legendary bakery where the original *Pastéis de Nata* (custard tarts) have been made since 1837 using a secret, ancient recipe from the Jerónimos Monastery. Enjoy them warm, dusted with cinnamon and powdered sugar.
#     *   For a more substantial lunch, you can find a local restaurant in Belém offering fresh seafood or other Portuguese specialties.
#
# *   **Afternoon (2:30 PM - 6:00 PM): Time Out Market & Riverside Atmosphere**
#     *   Head back towards the city center to the **Time Out Market (Mercado da Ribeira)** near Cais do Sodré. This vibrant food hall, which opened in 2014, features a wide array of stalls from top Portuguese chefs and traditional eateries, offering a fantastic opportunity to sample various local delicacies all in one place.
#     *   Afterward, you could take a leisurely stroll along the Cais do Sodré / Ribeira das Naus riverfront, enjoying the views of the Tagus River.
#
# *   **Evening (7:00 PM onwards): Dinner in Chiado or Bairro Alto**
#     *   Explore the elegant Chiado district, known for its historic cafés and theaters.
#     *   Enjoy your final dinner in Lisbon in either Chiado (for a more upscale experience) or the lively Bairro Alto (for traditional restaurants and a vibrant atmosphere). Consider trying another Portuguese classic like *Arroz de Marisco* (seafood rice) or *Polvo à Lagareiro* (roasted octopus).
#
# What do you think of this plan for Day 2? Does it capture your interests for historical sites and great local food?
# --------------------------------------------------

# %% [markdown]
# ### Scenario 3b: Agent WITHOUT Memory (Using SEPARATE Sessions) ❌
#
# Now, let's see what happens if we mess up our session management. Here, we'll give the agent a case of amnesia by creating a **brand new, separate session for each turn**.
#
# Pay close attention to the agent's response to the second query. Because it's in a new session, it has no memory of the trip to Lisbon we just discussed!

# %%
# --- Scenario 2b: Demonstrating Memory FAILURE ---

async def run_memory_failure_demonstration():
    print("\n" + "#"*60)
    print("### 🧠 DEMO 2b: AGENT WITH AMNESIA (SEPARATE SESSIONS) ###")
    print("#"*60)

    # --- Turn 1: The user initiates the trip in the FIRST session ---
    query1 = "Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food."
    session_one = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"\nCreated a session for Turn 1: {session_one.id}")
    print(f"🗣️ User (Turn 1): '{query1}'")
    await run_agent_query(multi_day_agent, query1, session_one, my_user_id)

    # --- Turn 2: The user asks to continue... but in a completely NEW session ---
    query2 = "Yes, that looks perfect! Please plan Day 2."
    session_two = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"\nCreated a BRAND NEW session for Turn 2: {session_two.id}")
    print(f"🗣️ User (Turn 2): '{query2}'")
    await run_agent_query(multi_day_agent, query2, session_two, my_user_id)

await run_memory_failure_demonstration()
# Out:
# ############################################################
# ### 🧠 DEMO 2b: AGENT WITH AMNESIA (SEPARATE SESSIONS) ###
# ############################################################
#
# Created a session for Turn 1: f15a8a75-bff0-467c-9245-1a7c118ecbe2
# 🗣️ User (Turn 1): 'Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'f15a8a75-bff0-467c-9245-1a7c118ecbe2'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Hello! Great choice, Lisbon is a beautiful city with so much history and delicious food to offer. I'll help you plan your 2-day trip.
#
# Let's start with **Day 1**. How does this sound?
#
# ### Day 1: Discovering Belém's Maritime History & Iconic Treats
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Belém**
#     *   Start your day at the magnificent **Jerónimos Monastery (Mosteiro dos Jerónimos)**, a UNESCO World Heritage site and a prime example of Manueline architecture.
#     *   Walk along the waterfront to the iconic **Belém Tower (Torre de Belém)**, another UNESCO site that served as a fortress and a departure point for explorers.
#     *   Visit the **Padrão dos Descobrimentos (Monument to the Discoveries)**, celebrating Portugal's Age of Exploration.
# *   **Lunch (1:00 PM - 2:30 PM): Authentic Pastéis de Nata**
#     *   Head to **Pastéis de Belém**, the original bakery, to savor warm, fresh *pastéis de nata* (custard tarts) dusted with cinnamon and powdered sugar. You can also grab a light lunch at a local restaurant in Belém.
# *   **Afternoon (2:30 PM - 6:00 PM): Belém Cultural Immersion**
#     *   Explore the **Museu Coleção Berardo**, a modern and contemporary art museum (if you're interested in art) or simply enjoy a leisurely walk along the Tagus River.
# *   **Evening (7:00 PM onwards): Alfama Charm & Traditional Dinner**
#     *   Take a tram or taxi to the historic **Alfama district**, Lisbon's oldest neighborhood, with its narrow, winding streets.
#     *   Enjoy a traditional Portuguese dinner at a local restaurant in Alfama, perhaps trying *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or fresh seafood.
#
# How does this sound for your first day in Lisbon?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=472,
#         start_index=251,
#         text="""*   **Morning (9:00 AM - 1:00 PM): Explore Belém**
#     *   Start your day at the magnificent **Jerónimos Monastery (Mosteiro dos Jerónimos)**, a UNESCO World Heritage site and a prime example of Manueline architecture."""
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=639,
#         start_index=477,
#         text='*   Walk along the waterfront to the iconic **Belém Tower (Torre de Belém)**, another UNESCO site that served as a fortress and a departure point for explorers.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=982,
#         start_index=763,
#         text="""*   **Lunch (1:00 PM - 2:30 PM): Authentic Pastéis de Nata**
#     *   Head to **Pastéis de Belém**, the original bakery, to savor warm, fresh *pastéis de nata* (custard tarts) dusted with cinnamon and powdered sugar."""
#       )
#     ),
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=446,
#   prompt_token_count=331,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=331
#     ),
#   ],
#   thoughts_token_count=166,
#   total_token_count=943
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-99e1f8f1-29d0-489e-a4a4-bc875fe023d4' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='986d02d5-9f93-4643-865d-31bdda03e514' timestamp=1769232849.181893
#
# --------------------------------------------------
# ✅ Final Response:
# Hello! Great choice, Lisbon is a beautiful city with so much history and delicious food to offer. I'll help you plan your 2-day trip.
#
# Let's start with **Day 1**. How does this sound?
#
# ### Day 1: Discovering Belém's Maritime History & Iconic Treats
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Belém**
#     *   Start your day at the magnificent **Jerónimos Monastery (Mosteiro dos Jerónimos)**, a UNESCO World Heritage site and a prime example of Manueline architecture.
#     *   Walk along the waterfront to the iconic **Belém Tower (Torre de Belém)**, another UNESCO site that served as a fortress and a departure point for explorers.
#     *   Visit the **Padrão dos Descobrimentos (Monument to the Discoveries)**, celebrating Portugal's Age of Exploration.
# *   **Lunch (1:00 PM - 2:30 PM): Authentic Pastéis de Nata**
#     *   Head to **Pastéis de Belém**, the original bakery, to savor warm, fresh *pastéis de nata* (custard tarts) dusted with cinnamon and powdered sugar. You can also grab a light lunch at a local restaurant in Belém.
# *   **Afternoon (2:30 PM - 6:00 PM): Belém Cultural Immersion**
#     *   Explore the **Museu Coleção Berardo**, a modern and contemporary art museum (if you're interested in art) or simply enjoy a leisurely walk along the Tagus River.
# *   **Evening (7:00 PM onwards): Alfama Charm & Traditional Dinner**
#     *   Take a tram or taxi to the historic **Alfama district**, Lisbon's oldest neighborhood, with its narrow, winding streets.
#     *   Enjoy a traditional Portuguese dinner at a local restaurant in Alfama, perhaps trying *Bacalhau à Brás* (codfish with scrambled eggs and potatoes) or fresh seafood.
#
# How does this sound for your first day in Lisbon?
# --------------------------------------------------
#
#
# Created a BRAND NEW session for Turn 2: a838643f-3307-44f3-bed6-ffc3e392796c
# 🗣️ User (Turn 2): 'Yes, that looks perfect! Please plan Day 2.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'a838643f-3307-44f3-bed6-ffc3e392796c'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Great! Let's plan out Day 2 of your Parisian adventure.
#
# **Day 2: Montmartre Charm & Opulent Architecture**
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Montmartre**
#     *   Start your day by heading to the charming artistic district of Montmartre.
#     *   Visit the stunning **Sacré-Cœur Basilica** for panoramic views of Paris and explore its beautiful interior.
#     *   Wander through **Place du Tertre**, where artists set up their easels, and soak in the bohemian atmosphere.
#     *   Discover the quieter streets and hidden gems of Montmartre.
# *   **Lunch (1:00 PM - 2:30 PM): Bistro lunch in Montmartre**
#     *   Enjoy a traditional French lunch at one of the many quaint bistros in Montmartre.
# *   **Afternoon (2:30 PM - 6:00 PM): Opéra Garnier**
#     *   Descend from Montmartre and head to the magnificent **Opéra Garnier**. Take a self-guided tour to admire its opulent architecture, grand staircase, and the famous ceiling painted by Chagall.
# *   **Evening (7:00 PM onwards): Dinner & Evening Stroll**
#     *   Savor a delicious dinner at a restaurant in the Opéra district or a nearby arrondissement, perhaps trying a different regional French cuisine.
#     *   After dinner, enjoy a leisurely evening stroll, perhaps past the illuminated department stores on Boulevard Haussmann or through the charming covered passages.
#
# How does this sound for your second day in Paris?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=351,
#   prompt_token_count=314,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=314
#     ),
#   ],
#   thoughts_token_count=325,
#   total_token_count=990
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-4d1f8bff-5871-47f5-bbbb-31f011a2f7d9' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='2a24415c-70f6-43eb-ba4e-5562d0bc4bca' timestamp=1769232853.290935
#
# --------------------------------------------------
# ✅ Final Response:
# Great! Let's plan out Day 2 of your Parisian adventure.
#
# **Day 2: Montmartre Charm & Opulent Architecture**
#
# *   **Morning (9:00 AM - 1:00 PM): Explore Montmartre**
#     *   Start your day by heading to the charming artistic district of Montmartre.
#     *   Visit the stunning **Sacré-Cœur Basilica** for panoramic views of Paris and explore its beautiful interior.
#     *   Wander through **Place du Tertre**, where artists set up their easels, and soak in the bohemian atmosphere.
#     *   Discover the quieter streets and hidden gems of Montmartre.
# *   **Lunch (1:00 PM - 2:30 PM): Bistro lunch in Montmartre**
#     *   Enjoy a traditional French lunch at one of the many quaint bistros in Montmartre.
# *   **Afternoon (2:30 PM - 6:00 PM): Opéra Garnier**
#     *   Descend from Montmartre and head to the magnificent **Opéra Garnier**. Take a self-guided tour to admire its opulent architecture, grand staircase, and the famous ceiling painted by Chagall.
# *   **Evening (7:00 PM onwards): Dinner & Evening Stroll**
#     *   Savor a delicious dinner at a restaurant in the Opéra district or a nearby arrondissement, perhaps trying a different regional French cuisine.
#     *   After dinner, enjoy a leisurely evening stroll, perhaps past the illuminated department stores on Boulevard Haussmann or through the charming covered passages.
#
# How does this sound for your second day in Paris?
# --------------------------------------------------

# %% [markdown]
# See? The agent was confused! It likely asked what destination or what trip we were talking about. Because the second query was in a fresh, isolated session, the agent had no memory of planning Day 1 in Lisbon.
#
# This perfectly illustrates why **managing sessions is the key to building truly conversational agents!**

# %% [markdown]
# ---
# ## 🎉 Congratulations! 🎉
#
# Congratulations on completing your ADK adventure into Tools and Memory! You've taken a massive leap from building single-shot agents to creating dynamic, stateful AI systems.
#
# Let's recap the powerful concepts you've mastered:
#
# - **Fundamental Agent & Tools**: You started by building a "Day Trip Genie" and equipped it with its first tool, GoogleSearch.
#
# - **Custom Function Tools**: You gave your agent a new sense by creating a custom tool to fetch live data from the U.S. National Weather Service API.
#
# - **Agent-as-a-Tool**: You orchestrated a sophisticated hierarchy where agents delegate tasks to other, more specialized agents, creating a collaborative team.
#
# - **The Power of Memory**: Most importantly, you saw firsthand how managing a single, persistent Session allows an agent to remember context, adapt to user feedback, and conduct a meaningful, multi-turn conversation.

# %% [markdown]
# ```
#    __            /\_/\         /\_/\        /\_/\         __             (\__/)
# o-''|\_____/).  ( o.o )       ( -.- )      ( ^_^ )     o-''|\_____/).    ( ^_^ )
#  \_/|_)     )    > ^ <         > * <        >💖<         \_/|_)     )     / >🌸< \
#     \  __  /                                              \  __  /         /   \
#     (_/ (_/                                               (_/ (_/        (___|___)
# ```
